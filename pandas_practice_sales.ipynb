# %%
import pandas as pd

# %%
sales = pd.read_csv('sales.csv')

# %%
sales.head()
# Out:
#       Product     Category  Price  Quantity
# 0       Phone  Electronics  60000        10
# 1      Laptop  Electronics  80000         5
# 2     Monitor  Electronics  12500         8
# 3      Tablet  Electronics  35000         6
# 4  Smartwatch  Electronics   8500        15

# %%
sales['GST_percent'] = 18

# %%
sales.head()
# Out:
#       Product     Category  Price  Quantity  GST_percent
# 0       Phone  Electronics  60000        10           18
# 1      Laptop  Electronics  80000         5           18
# 2     Monitor  Electronics  12500         8           18
# 3      Tablet  Electronics  35000         6           18
# 4  Smartwatch  Electronics   8500        15           18

# %%
sales.drop(columns = ['Phone'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sales.drop(columns = ['Phone'])
#
# File c:\Users\yashg\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\Users\yashg\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
# ...

# %%
gst = {
    'Electronics': 18,
    'Accessories': 5,
    'Stationery' : 0,
    'Furniture' : 15
}

sales['GST_percentage'] = sales['Category'].map(gst)

# %%
sales
# Out:
#          Product     Category  Price  Quantity  Phone  GST_percent  \
# 0          Phone  Electronics  60000        10  75999           18
# 1         Laptop  Electronics  80000         5  75999           18
# 2        Monitor  Electronics  12500         8  75999           18
# 3         Tablet  Electronics  35000         6  75999           18
# 4     Smartwatch  Electronics   8500        15  75999           18
# 5          Mouse  Accessories   1500        50  75999           18
# 6       Keyboard  Accessories   2500        20  75999           18
# 7      USB Cable  Accessories    300       100  75999           18
# 8     Headphones  Accessories   2000        30  75999           18
# 9         Webcam  Accessories   3500        12  75999           18
# 10      Notebook   Stationery     50       200  75999           18
# 11           Pen   Stationery     10       500  75999           18
# 12       Stapler   Stationery    150        40  75999           18
# ...

# %%
sales.drop(columns = ['Phone'], inplace = True)

# %%
sales
# Out:
#          Product     Category  Price  Quantity  GST_percent  GST_percentage
# 0          Phone  Electronics  60000        10           18              18
# 1         Laptop  Electronics  80000         5           18              18
# 2        Monitor  Electronics  12500         8           18              18
# 3         Tablet  Electronics  35000         6           18              18
# 4     Smartwatch  Electronics   8500        15           18              18
# 5          Mouse  Accessories   1500        50           18               5
# 6       Keyboard  Accessories   2500        20           18               5
# 7      USB Cable  Accessories    300       100           18               5
# 8     Headphones  Accessories   2000        30           18               5
# 9         Webcam  Accessories   3500        12           18               5
# 10      Notebook   Stationery     50       200           18               0
# ...

# %%
sales.drop(columns = ['GST_percent'], inplace = True)

# %%
sales
# Out:
#          Product     Category  Price  Quantity  GST_percentage
# 0          Phone  Electronics  60000        10              18
# 1         Laptop  Electronics  80000         5              18
# 2        Monitor  Electronics  12500         8              18
# 3         Tablet  Electronics  35000         6              18
# 4     Smartwatch  Electronics   8500        15              18
# 5          Mouse  Accessories   1500        50               5
# 6       Keyboard  Accessories   2500        20               5
# 7      USB Cable  Accessories    300       100               5
# 8     Headphones  Accessories   2000        30               5
# 9         Webcam  Accessories   3500        12               5
# 10      Notebook   Stationery     50       200               0
# 11           Pen   Stationery     10       500               0
# 12       Stapler   Stationery    150        40               0
# 13     Desk Lamp    Furniture   1200        25              15
# ...
