# %%
import pandas as pd

# %%
bios = pd.read_csv('athlete_events.csv')

# %%
bios.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
bios.loc[1:15]
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# 11   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %%
bios.iloc[0:5,[0,3]]
# Out:
#    ID   Age
# 0   1  24.0
# 1   2  23.0
# 2   3  24.0
# 3   4  34.0
# 4   5  21.0

# %%
bios.loc[bios['Height'] > 215,['Name','Height','Weight']]
# Out:
#                                                      Name  Height  Weight
# 14132                                         Stanko Bara   217.0   110.0
# 17669                                      Gunther Behnke   221.0   114.0
# 22743                                            Uwe Blab   218.0   110.0
# 22744                                            Uwe Blab   218.0   110.0
# 32376                                Tommy Loren Burleson   223.0   102.0
# 34307                              Andrew "Andy" Campbell   218.0    93.0
# 34308                              Andrew "Andy" Campbell   218.0    93.0
# 38381                              Tyson Cleotis Chandler   216.0   107.0
# 47982                                 Paulo Csar da Silva   217.0   106.0
# 59371                              Roberto Dueas Hernndez   221.0   137.0
# 59372                              Roberto Dueas Hernndez   221.0   137.0
# 80447                                 Andreas Glyniadakis   216.0   115.0
# ...

# %%
bios[(bios['Height'] > 200)]
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 299        161              Hossam Abdalla   M  28.0   203.0    97.0
# 443        246          Mamdouh Abdelrehim   M  26.0   207.0    90.0
# 609        351  Julius Shareef Abdur-Rahim   M  23.0   202.0   104.0
# 820        468    Abdelhalim Muhammad Abou   M  27.0   210.0    88.0
# 833        474     Essameldin Abou El-Nein   M  29.0   205.0   102.0
# ...        ...                         ...  ..   ...     ...     ...
# 270741  135401          Eurelijus ukauskas   M  27.0   218.0   115.0
# 270742  135401          Eurelijus ukauskas   M  30.0   218.0   115.0
# 270743  135402          Mindaugas ukauskas   M  20.0   201.0   100.0
# 270744  135402          Mindaugas ukauskas   M  28.0   201.0   100.0
# 271026  135530              Philip Zwiener   M  23.0   202.0    98.0
#
#                  Team  NOC        Games  Year  Season            City  \
# ...

# %%
bios[(bios['Weight'] > 75) & (bios['Event'] == "Basketball Men's Basketball")]
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 264        136                    Alessandro Abbio   M  29.0   195.0    85.0
# 346        192  Ahmed El-Sayed Abdel Hamid Mobarak   M  25.0   189.0    85.0
# 363        202                Awad Abdel Nabi Awad   M  19.0   198.0    80.0
# 364        202                Awad Abdel Nabi Awad   M  23.0   198.0    80.0
# ...        ...                                 ...  ..   ...     ...     ...
# 270741  135401                  Eurelijus ukauskas   M  27.0   218.0   115.0
# 270742  135401                  Eurelijus ukauskas   M  30.0   218.0   115.0
# 270743  135402                  Mindaugas ukauskas   M  20.0   201.0   100.0
# 270744  135402                  Mindaugas ukauskas   M  28.0   201.0   100.0
# 271026  135530                      Philip Zwiener   M  23.0   202.0    98.0
#
# ...

# %%
bios[bios['City'].isin(["USA"])]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
bios_new = bios.copy()

# %%
bios_new.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
bios_new["first_name"] = bios_new['Name'].str.split(" ").str[0]

# %%
bios_new.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal first_name
# 0       Basketball Men's Basketball   NaN          A
# ...
